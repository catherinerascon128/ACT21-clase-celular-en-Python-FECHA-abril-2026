# %% [markdown]
# <a href="https://colab.research.google.com/github/catherinerascon128/ACT21-clase-celular-en-Python-FECHA-abril-2026/blob/main/Act_21_clase_celular_catherine_rascon_0072.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### catherine rascon NL = 26 Fecha 22/abril/2026
# ## clase celular
# ![texto del vínculo](https://raw.githubusercontent.com/catherinerascon128/ACT21-clase-celular-en-Python-FECHA-abril-2026/refs/heads/main/infoclasecelular.png)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# Instanciación
cel1 = Celular("Samsung", "Galaxy S23", 800)
cel2 = Celular("Apple", "iPhone 15", 1000)

# llamar a las funciones para cada objeto celular 1 y celular 2
print("celular 1 😁")
cel1.mostrar_info()
cel1.encender()
print("-------------------------------")

print("celular 2 😊")
cel2.mostrar_info()
cel2.encender()

print("programacion terminada")
print("creador de sofware por catherine rascon NL = 26")
# Out:
# celular 1 😁
# Celular: Samsung Galaxy S23, Precio: $800
# El Galaxy S23 se ha encendido.
# -------------------------------
# celular 2 😊
# Celular: Apple iPhone 15, Precio: $1000
# El iPhone 15 se ha encendido.
# programacion terminada
# creador de sofware por catherine rascon NL = 26

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/catherinerascon128/ACT21-clase-celular-en-Python-FECHA-abril-2026/refs/heads/main/logiacaFuncionamiento.png)
